# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
from datetime import timedelta
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
cities_df = pd.read_csv('Resources/cities.csv')
cities_df.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
#
#       Lng  Max Temp  Wind Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# 3   78.62     59.89        0.94
# 4  147.90     32.17        2.95

# %%
# Create html table
table = cities_df.to_html(classes="table table-hover table-light", index = False)
table = table.replace('\n', '')
table
# Out:
# '<table border="1" class="dataframe table table-hover table-light">  <thead>    <tr style="text-align: right;">      <th>City_ID</th>      <th>City</th>      <th>Cloudiness</th>      <th>Country</th>      <th>Date</th>      <th>Humidity</th>      <th>Lat</th>      <th>Lng</th>      <th>Max Temp</th>      <th>Wind Speed</th>    </tr>  </thead>  <tbody>    <tr>      <td>0</td>      <td>jacareacanga</td>      <td>0</td>      <td>BR</td>      <td>1528902000</td>      <td>62</td>      <td>-6.22</td>      <td>-57.76</td>      <td>89.60</td>      <td>6.93</td>    </tr>    <tr>      <td>1</td>      <td>kaitangata</td>      <td>100</td>      <td>NZ</td>      <td>1528905304</td>      <td>94</td>      <td>-46.28</td>      <td>169.85</td>      <td>42.61</td>      <td>5.64</td>    </tr>    <tr>      <td>2</td>      <td>goulburn</td>      <td>20</td>      <td>AU</td>      <td>1528905078</td>      <td>91</td>      <td>-34.75</td>      <td>149.72</td>      <td>44.32</td>      <td>10.11</td>    </tr>
# ...

# %%
# Plot a scattergram showing Lat vs Humidity
x_values = cities_df['Lat']
y_values = cities_df['Humidity']
plt.scatter(x_values,y_values, edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('City Latitude vs Humidity ("01/05/17")')
plt.grid(color="gray",linestyle = "solid")
plt.savefig("Images/Humidity.png")
plt.show()

# %%
# Plot a scattergram showing Lat vs Humidity
x_values = cities_df['Lat']
y_values = cities_df['Humidity']
plt.scatter(x_values,y_values, edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('City Latitude vs Humidity ("01/05/17")')
plt.grid(color="gray",linestyle = "solid")
plt.savefig("Images/Humidity.png")
plt.show()

# %%
# Plot a scattergram showing Lat vs Cloudiness
x_values = cities_df['Lat']
y_values = cities_df['Cloudiness']
plt.scatter(x_values,y_values, edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('City Latitude vs Cloudiness ("01/05/17")')
plt.grid(color="gray",linestyle = "solid")
plt.savefig("Images/Cloudiness.png")
plt.show()

# %%
# Plot a scattergram showing Lat vs Wind Speed
x_values = cities_df['Lat']
y_values = cities_df['Wind Speed']
plt.scatter(x_values,y_values, edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('City Latitude vs Wind Speed("01/05/17")')
plt.grid(color="gray",linestyle = "solid")
plt.savefig("Images/Wind_speed.png")
plt.show()
